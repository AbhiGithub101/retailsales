# %%
import pandas as pd   
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('amazon.xlsx')
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %%
ndf = df['Customer Type'].value_counts().reset_index()
ndf
# Out:
#   Customer Type  count
# 0      Consumer    417
# 1     Corporate    251
# 2   Home Office    160

# %%
plt.pie(ndf['count'],labels=ndf['Customer Type'],autopct='%.1f%%',colors=['green','blue','red'])


plt.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Pie(
    labels=ndf['Customer Type'],
    values=ndf['count'],
    textinfo='percent',
    hoverinfo='label+percent',
    marker=dict(colors=['green', 'blue', 'red'])
)])

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=False)

fig.show()

# %%
ndf
# Out:
#         Product  total
# 0   Accessories    206
# 1    Appliances    734
# 2       Binders     81
# 3     Bookcases    639
# 4        Chairs    598
# 5       Copiers    753
# 6      Machines    347
# 7        Phones    932
# 8       Storage    239
# 9      Supplies     35
# 10       Tables    515

# %%
ndf = df.groupby('Product').agg(
    total = ('Quantity','sum')
).reset_index()


l = []

for i in ndf['total']:
    if(i>=500):
        l.append('green')
    else:
        l.append('red')

plt.figure(figsize=(10,5))

plt.bar(ndf['Product'],ndf['total'],color=l)  

plt.xticks(rotation=45)

for m,n in zip(ndf['Product'],ndf['total']):
    plt.text(x=m,y=n,s=n,ha='center',va='bottom')

plt.grid()
plt.show()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Year'] = df['Order Date'].dt.year   
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 1      IN-2013-77878 2013-02-05 2013-02-07    Second Class    JR-16210
# 2      IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 3    ES-2013-1579342 2013-01-28 2013-01-30     First Class    KM-16375
# 4       SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# ..               ...        ...        ...             ...         ...
# 823   CA-2013-101546 2013-12-19 2013-12-25  Standard Class    GK-14620
# 824   CA-2014-154410 2014-10-22 2014-10-25     First Class    MD-17860
# 825    ID-2012-31118 2012-12-26 2012-12-28    Second Class    TH-21550
# 826    IN-2013-65677 2013-10-11 2013-10-14     First Class    HD-14785
# 827    ID-2012-39875 2012-04-25 2012-04-27    Second Class    TP-21130
#
#          Customer Name Customer Type           City            State  \
# ...

# %%
ndf
# Out:
#    Year   total_sales  total_profit
# 0  2011  346027.73446   64894.06296
# 1  2012  368975.44166   51475.36366
# 2  2013  515047.22180   98375.46250
# 3  2014  657953.46920  117825.41600

# %%
ndf = df.groupby('Year').agg(
    total_sales = ('Sales','sum'),
    total_profit = ('Profit','sum')
).reset_index()


plt.figure(figsize=(12,6))
ndf['Year'] = ndf['Year'].astype(str)
plt.plot(ndf['Year'],ndf['total_sales'],marker='o',label='Sales')
plt.plot(ndf['Year'],ndf['total_profit'],marker='o',label='Profit')

for m,n in zip(ndf['Year'],ndf['total_sales']):
    plt.text(x=m,y=n,s=round(n),ha='center',va='bottom',color='green')

for m,n in zip(ndf['Year'],ndf['total_profit']):
    plt.text(x=m,y=n,s=round(n),ha='center',va='bottom',color='green')

plt.grid()
plt.legend()
plt.show()

# %%
ndf = df.groupby('Country').agg(
    total_sales =('Profit','sum')
).reset_index()

plt.figure(figsize=(15,5))

ndf = ndf.sort_values(by='total_sales',ascending=False)   
plt.bar(ndf['Country'],ndf['total_sales'])


plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,15))

plt.barh(ndf['Country'],ndf['total_sales'])


plt.show()
